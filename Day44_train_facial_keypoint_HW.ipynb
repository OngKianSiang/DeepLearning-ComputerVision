# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 3s 2ms/step - loss: 0.0083 - val_loss: 0.0025
#
# Epoch 00001: val_loss improved from inf to 0.00248, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 340us/step - loss: 0.0022 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00248 to 0.00199, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00199 to 0.00195, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00195 to 0.00192, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 1s 339us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00192 to 0.00186, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 1s 334us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00186 to 0.00184, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 1s 335us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00007: val_loss did not improve from 0.00184
# Epoch 8/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 9.5034e-04 - val_loss: 0.0018
#
# Epoch 00008: val_loss improved from 0.00184 to 0.00176, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 333us/step - loss: 8.1399e-04 - val_loss: 0.0016
#
# Epoch 00009: val_loss improved from 0.00176 to 0.00164, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 339us/step - loss: 7.1189e-04 - val_loss: 0.0015
#
# Epoch 00010: val_loss improved from 0.00164 to 0.00155, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 6.5291e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00155 to 0.00134, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 340us/step - loss: 5.7135e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00134 to 0.00126, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 1s 334us/step - loss: 5.2804e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00126 to 0.00117, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 4.8255e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00117 to 0.00109, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 339us/step - loss: 4.7868e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00109
# Epoch 16/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 4.4001e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00109 to 0.00102, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 4.1329e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss did not improve from 0.00102
# Epoch 18/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 3.8659e-04 - val_loss: 9.6479e-04
#
# Epoch 00018: val_loss improved from 0.00102 to 0.00096, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 3.6411e-04 - val_loss: 9.4892e-04
#
# Epoch 00019: val_loss improved from 0.00096 to 0.00095, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 3.6590e-04 - val_loss: 9.3416e-04
#
# Epoch 00020: val_loss improved from 0.00095 to 0.00093, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 3.3808e-04 - val_loss: 9.3076e-04
#
# Epoch 00021: val_loss improved from 0.00093 to 0.00093, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 1s 334us/step - loss: 3.2767e-04 - val_loss: 9.4409e-04
#
# Epoch 00022: val_loss did not improve from 0.00093
# Epoch 23/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 3.2324e-04 - val_loss: 8.8487e-04
#
# Epoch 00023: val_loss improved from 0.00093 to 0.00088, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 3.1083e-04 - val_loss: 8.7518e-04
#
# Epoch 00024: val_loss improved from 0.00088 to 0.00088, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 3.0758e-04 - val_loss: 8.4578e-04
#
# Epoch 00025: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 1s 335us/step - loss: 2.9363e-04 - val_loss: 8.5583e-04
#
# Epoch 00026: val_loss did not improve from 0.00085
# Epoch 27/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.8368e-04 - val_loss: 8.5519e-04
#
# Epoch 00027: val_loss did not improve from 0.00085
# Epoch 28/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.8417e-04 - val_loss: 8.7687e-04
#
# Epoch 00028: val_loss did not improve from 0.00085
# Epoch 29/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 2.7499e-04 - val_loss: 8.5539e-04
#
# Epoch 00029: val_loss did not improve from 0.00085
# Epoch 30/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 2.6801e-04 - val_loss: 8.5150e-04
#
# Epoch 00030: val_loss did not improve from 0.00085
# Epoch 31/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.6203e-04 - val_loss: 8.3371e-04
#
# Epoch 00031: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 2.5609e-04 - val_loss: 8.3217e-04
#
# Epoch 00032: val_loss improved from 0.00083 to 0.00083, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.4946e-04 - val_loss: 8.4214e-04
#
# Epoch 00033: val_loss did not improve from 0.00083
# Epoch 34/150
# 1712/1712 [==============================] - 1s 334us/step - loss: 2.5348e-04 - val_loss: 8.3383e-04
#
# Epoch 00034: val_loss did not improve from 0.00083
# Epoch 35/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 2.4418e-04 - val_loss: 7.8812e-04
#
# Epoch 00035: val_loss improved from 0.00083 to 0.00079, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.3555e-04 - val_loss: 8.3428e-04
#
# Epoch 00036: val_loss did not improve from 0.00079
# Epoch 37/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.3038e-04 - val_loss: 8.4371e-04
#
# Epoch 00037: val_loss did not improve from 0.00079
# Epoch 38/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.2971e-04 - val_loss: 9.3244e-04
#
# Epoch 00038: val_loss did not improve from 0.00079
# Epoch 39/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 2.3006e-04 - val_loss: 8.2610e-04
#
# Epoch 00039: val_loss did not improve from 0.00079
# Epoch 40/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 2.1813e-04 - val_loss: 8.2904e-04
#
# Epoch 00040: val_loss did not improve from 0.00079
# Epoch 41/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 2.1635e-04 - val_loss: 8.3800e-04
#
# Epoch 00041: val_loss did not improve from 0.00079
# Epoch 42/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 2.1434e-04 - val_loss: 8.1079e-04
#
# Epoch 00042: val_loss did not improve from 0.00079
# Epoch 43/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 2.1771e-04 - val_loss: 8.2756e-04
#
# Epoch 00043: val_loss did not improve from 0.00079
# Epoch 44/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 2.1175e-04 - val_loss: 8.2494e-04
#
# Epoch 00044: val_loss did not improve from 0.00079
# Epoch 45/150
# 1712/1712 [==============================] - 1s 333us/step - loss: 2.0408e-04 - val_loss: 7.8940e-04
#
# Epoch 00045: val_loss did not improve from 0.00079
# Epoch 46/150
# 1712/1712 [==============================] - 1s 333us/step - loss: 2.0228e-04 - val_loss: 7.9398e-04
#
# Epoch 00046: val_loss did not improve from 0.00079
# Epoch 47/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 2.0129e-04 - val_loss: 7.9605e-04
#
# Epoch 00047: val_loss did not improve from 0.00079
# Epoch 48/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 1.9953e-04 - val_loss: 8.3016e-04
#
# Epoch 00048: val_loss did not improve from 0.00079
# Epoch 49/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 1.9793e-04 - val_loss: 8.1758e-04
#
# Epoch 00049: val_loss did not improve from 0.00079
# Epoch 50/150
# 1712/1712 [==============================] - 1s 340us/step - loss: 1.9174e-04 - val_loss: 7.8081e-04
#
# Epoch 00050: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 1s 333us/step - loss: 1.9164e-04 - val_loss: 7.8548e-04
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 1.8404e-04 - val_loss: 7.6572e-04
#
# Epoch 00052: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 1.8357e-04 - val_loss: 7.8377e-04
#
# Epoch 00053: val_loss did not improve from 0.00077
# Epoch 54/150
# 1712/1712 [==============================] - 1s 340us/step - loss: 1.8204e-04 - val_loss: 7.7648e-04
#
# Epoch 00054: val_loss did not improve from 0.00077
# Epoch 55/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 1.8692e-04 - val_loss: 8.1784e-04
#
# Epoch 00055: val_loss did not improve from 0.00077
# Epoch 56/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 1.8729e-04 - val_loss: 7.9730e-04
#
# Epoch 00056: val_loss did not improve from 0.00077
# Epoch 57/150
# 1712/1712 [==============================] - 1s 342us/step - loss: 1.7763e-04 - val_loss: 7.9430e-04
#
# Epoch 00057: val_loss did not improve from 0.00077
# Epoch 58/150
# 1712/1712 [==============================] - 1s 333us/step - loss: 1.7251e-04 - val_loss: 7.9400e-04
#
# Epoch 00058: val_loss did not improve from 0.00077
# Epoch 59/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 1.7100e-04 - val_loss: 8.5844e-04
#
# Epoch 00059: val_loss did not improve from 0.00077
# Epoch 60/150
# 1712/1712 [==============================] - 1s 335us/step - loss: 1.7431e-04 - val_loss: 8.0873e-04
#
# Epoch 00060: val_loss did not improve from 0.00077
# Epoch 61/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 1.7123e-04 - val_loss: 7.8634e-04
#
# Epoch 00061: val_loss did not improve from 0.00077
# Epoch 62/150
# 1712/1712 [==============================] - 1s 334us/step - loss: 1.6642e-04 - val_loss: 7.9140e-04
#
# Epoch 00062: val_loss did not improve from 0.00077
# Epoch 63/150
# 1712/1712 [==============================] - 1s 333us/step - loss: 1.6554e-04 - val_loss: 7.9064e-04
#
# Epoch 00063: val_loss did not improve from 0.00077
# Epoch 64/150
# 1712/1712 [==============================] - 1s 337us/step - loss:
-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 1s 343us/step - loss: 1.1002e-04 - val_loss: 7.7301e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 1.0397e-04 - val_loss: 8.1864e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 1.0226e-04 - val_loss: 8.0259e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 1.0257e-04 - val_loss: 8.1304e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 1.0433e-04 - val_loss: 7.9694e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 1.0161e-04 - val_loss: 8.0173e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 1.0178e-04 - val_loss: 7.8876e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 1s 343us/step - loss: 9.8683e-05 - val_loss: 7.9392e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 1.0061e-04 - val_loss: 7.9273e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 9.8499e-05 - val_loss: 8.1971e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 1s 335us/step - loss: 9.6485e-05 - val_loss: 8.0018e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 9.8917e-05 - val_loss: 8.2671e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 9.6380e-05 - val_loss: 7.8994e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 9.7490e-05 - val_loss: 7.7302e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 9.4812e-05 - val_loss: 7.7528e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 9.4890e-05 - val_loss: 7.7927e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 9.4907e-05 - val_loss: 7.7059e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 9.6611e-05 - val_loss: 8.5405e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 9.3828e-05 - val_loss: 8.0456e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 9.4364e-05 - val_loss: 8.0255e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 9.3849e-05 - val_loss: 8.1630e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 9.3621e-05 - val_loss: 8.2223e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 9.4164e-05 - val_loss: 7.8903e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 1s 338us/step - loss: 8.9939e-05 - val_loss: 8.2874e-04
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 9.1465e-05 - val_loss: 7.9257e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 9.0026e-05 - val_loss: 8.1257e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 9.0234e-05 - val_loss: 7.8215e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 1s 335us/step - loss: 8.9419e-05 - val_loss: 8.1030e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 1s 336us/step - loss: 9.0891e-05 - val_loss: 7.9352e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 1s 337us/step - loss: 8.7683e-05 - val_loss: 8.0660e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 1s 345us/step - loss: 8.8000e-05 - val_loss: 7.9079e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 1s 341us/step - loss: 8.6803e-05 - val_loss: 8.0164e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
def load_data_filp(img, points):
    
    rows, cols = img.shape
    img_filp = np.copy(img)
    
    for i in range(rows):
        for j in range(cols):
            tmp = img[i][j]
            img_filp[i][j] = img[i][cols-j-1]
            img_filp[i][cols-j-1] = tmp
    
    points_filp = np.copy(points)
    
    for i in range(0, 30, 2):
        points_filp[i] = -points[i]
        
    points_tmp = np.copy(points_filp)
    points_filp[0:2] = points_tmp[2:4]
    points_filp[2:4] = points_tmp[0:2]
    points_filp[4:6] = points_tmp[8:10]
    points_filp[6:8] = points_tmp[10:12]
    points_filp[8:10] = points_tmp[4:6]
    points_filp[10:12] = points_tmp[6:8]
    points_filp[12:14] = points_tmp[16:18]
    points_filp[14:16] = points_tmp[18:20]
    points_filp[16:18] = points_tmp[12:14]
    points_filp[18:20] = points_tmp[14:16]
    points_filp[22:24] = points_tmp[24:26]
    points_filp[24:26] = points_tmp[22:24]
    
    return img_filp, points_filp

# %%
aug_imgs_train = []
aug_points_train = []

for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = load_data_filp(imgs_train[i], points_train[i])

    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
plot_keypoints(imgs_train[1], points_train[1])

# %%
aug_img, aug_point = load_data_filp(imgs_train[1], points_train[1])
plot_keypoints(aug_img, aug_point)
